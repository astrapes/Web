# %% [markdown]
# # 시카고 샌드위치 맛집 분석

# %% [markdown]
# ## 1. 시카고 샌드위치 맛집 사이트에 접근하기

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url_base = 'https://www.chicagomag.com'
url_sub = '/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'
url = url_base + url_sub

html = urlopen(url)
soup = BeautifulSoup(html,'html.parser')

# %%
rest_list = soup.find_all(class_='sammy')
rest_list
# Out:
# [<div class="sammy" style="position: relative;">
#  <div class="sammyRank">1</div>
#  <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br>
#  Old Oak Tap<br>
#  <em>Read more</em> </br></br></a></div>
#  </div>,
#  <div class="sammy" style="position: relative;">
#  <div class="sammyRank">2</div>
#  <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
#  Au Cheval<br/>
#  <em>Read more</em> </a></div>
#  </div>,
#  <div class="sammy" style="position: relative;">
#  <div class="sammyRank">3</div>
#  <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
#  Xoco<br/>
#  <em>Read more</em> </a></div>
#  </div>,
#  <div class="sammy" style="position: relative;">
#  <div class="sammyRank">4</div>
# ...

# %%
len(rest_list)
# Out:
# 50

# %% [markdown]
# ## 2. 접근한 웹 페이지에서 원하는 데이터 추출하고 정리하기.

# %%
tmp_one = rest_list[0]
tmp_one
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br>
# Old Oak Tap<br>
# <em>Read more</em> </br></br></a></div>
# </div>

# %%
# 랭킹
tmp_one.find(class_ = 'sammyRank').get_text()
# Out:
# '1'

# %%
#메뉴 이름
tmp_one.find(class_ = 'sammyListing').get_text()
# Out:
# 'BLT\r\nOld Oak Tap\nRead more '

# %%
tmp_str = tmp_one.find(class_ = 'sammyListing').get_text()
tmp_str.split('\n')
# Out:
# ['BLT\r', 'Old Oak Tap', 'Read more ']

# %%
tmp_res = tmp_str.split('\n')
menu = tmp_res[0].replace('\r','')
menu
# Out:
# 'BLT'

# %%
cafe = tmp_res[1]
cafe
# Out:
# 'Old Oak Tap'

# %%
# *Regular expression
# 생활코딩 https://opentutorials.org/course/1
import re

# %%
re.split(('\n|\r\n'),tmp_str)
# Out:
# ['BLT', 'Old Oak Tap', 'Read more ']

# %%
print(re.split(('\n|\r\n'),tmp_str)[0],
      re.split(('\n|\r\n'),tmp_str)[1])
# Out:
# BLT Old Oak Tap

# %%
# 웹 사이트 링크
tmp_one.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %% [markdown]
# ## 데이터 프레임 만들기 전, 항목 데이터 구하기

# %%
from urllib.parse import urljoin

# %%
rank = []
main_menu = []
cafe_name = []
url_add = []

for rest in rest_list:
    rank.append(int(rest.find(class_ = 'sammyRank').get_text()))
    tmp_str = rest.find(class_ = 'sammyListing').get_text()
    main_menu.append(re.split(('\n|\r\n'),tmp_str)[0])
    cafe_name.append(re.split(('\n|\r\n'),tmp_str)[1])
    url_add.append(urljoin(url_base,rest.find('a')['href']))

# %%
main_menu[:5]
# Out:
# ['BLT', 'Fried Bologna', 'Woodland Mushroom', 'Roast Beef', 'PB&L']

# %%
cafe_name[:5]
# Out:
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']

# %%
url_add[0:20]
# Out:
# ['https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/',
#  'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Hendrickx-Belgian-Bread-Crafter-Belgian-Chicken-Curry-Salad/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Acadia-Lobster-Roll/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Birchwood-Kitchen-Smoked-Salmon-Salad/',
# ...

# %%
# 데이터 프레임으로 만들기
import pandas as pd

# %%
df = pd.DataFrame({'Rank':rank,'Cafe' : cafe_name, 'Menu' : main_menu,'URL' : url_add})
df.head(50)
# Out:
#     Rank                             Cafe  \
# 0      1                      Old Oak Tap
# 1      2                        Au Cheval
# 2      3                             Xoco
# 3      4                        Al’s Deli
# 4      5           Publican Quality Meats
# 5      6  Hendrickx Belgian Bread Crafter
# 6      7                           Acadia
# 7      8                Birchwood Kitchen
# 8      9                   Cemitas Puebla
# 9     10                             Nana
# 10    11                        Lula Cafe
# 11    12                       Ricobene’s
# 12    13                     Frog n Snail
# 13    14                 Crosby’s Kitchen
# 14    15                  Longman & Eagle
# 15    16                             Bari
# 16    17                          Manny’s
# 17    18                           Eggy’s
# 18    19                    Old Jerusalem
# 19    20             Mindy’s HotChocolate
# 20    21              Olga’s Delicatessen
# ...

# %%
df.to_csv('chicago1.csv',sep=',',encoding ='utf-8')

# %% [markdown]
# ## 3. 다수의 웹 페이지에 자동으로 접근해서 원하는 정보 가져오기.

# %%
df['URL'][0]
# Out:
# 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
html = urlopen(df['URL'][0])
soup_tmp = BeautifulSoup(html,'html.parser')

# %%
tmp_str = soup_tmp.find(class_='addy').get_text()
tmp_str
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
tmp_str.split()
# Out:
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']

# %%
tmp_price = tmp_str.split()[0][:-1]
tmp_price
# Out:
# '$10'

# %%
tmp_str.split()[1:-2]
# Out:
# ['2109', 'W.', 'Chicago', 'Ave.,']

# %%
' '.join(tmp_str.split()[1:-2])
# Out:
# '2109 W. Chicago Ave.,'

# %%
tmp_addr = ' '.join(tmp_str.split()[1:-2])[:-1]
tmp_addr
# Out:
# '2109 W. Chicago Ave.'

# %% [markdown]
# # - 상태 진행바 적용

# %%
from tqdm.notebook import tqdm
import time

# %%
price = []
addr = []
for n in tqdm_notebook(df.index):
    html = urlopen(df['URL'][n])
    soup_tmp = BeautifulSoup(html,'html.parser')
    tmp_str = soup_tmp.find(class_='addy').get_text()
    
    price.append(tmp_str.split()[0][:-1])
    addr.append(' '.join(tmp_str.split()[1:-2])[:-1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
price[:4]
# Out:
# ['$10', '$9', '$9.50', '$9.40']

# %%
addr[:4]
# Out:
# ['2109 W. Chicago Ave.',
#  '800 W. Randolph St.',
#  '445 N. Clark St.',
#  '914 Noyes St., Evanston']

# %%
# del df['URL']
df2 = df.iloc[:,:-1]
df2
# Out:
#     Rank                             Cafe  \
# 0      1                      Old Oak Tap
# 1      2                        Au Cheval
# 2      3                             Xoco
# 3      4                        Al’s Deli
# 4      5           Publican Quality Meats
# 5      6  Hendrickx Belgian Bread Crafter
# 6      7                           Acadia
# 7      8                Birchwood Kitchen
# 8      9                   Cemitas Puebla
# 9     10                             Nana
# 10    11                        Lula Cafe
# 11    12                       Ricobene’s
# 12    13                     Frog n Snail
# 13    14                 Crosby’s Kitchen
# 14    15                  Longman & Eagle
# 15    16                             Bari
# 16    17                          Manny’s
# 17    18                           Eggy’s
# 18    19                    Old Jerusalem
# 19    20             Mindy’s HotChocolate
# 20    21              Olga’s Delicatessen
# ...

# %%
df2['Price'] = price

# %%
df2['Address'] = addr

# %%
df2
# Out:
#     Rank                             Cafe  \
# 0      1                      Old Oak Tap
# 1      2                        Au Cheval
# 2      3                             Xoco
# 3      4                        Al’s Deli
# 4      5           Publican Quality Meats
# 5      6  Hendrickx Belgian Bread Crafter
# 6      7                           Acadia
# 7      8                Birchwood Kitchen
# 8      9                   Cemitas Puebla
# 9     10                             Nana
# 10    11                        Lula Cafe
# 11    12                       Ricobene’s
# 12    13                     Frog n Snail
# 13    14                 Crosby’s Kitchen
# 14    15                  Longman & Eagle
# 15    16                             Bari
# 16    17                          Manny’s
# 17    18                           Eggy’s
# 18    19                    Old Jerusalem
# 19    20             Mindy’s HotChocolate
# 20    21              Olga’s Delicatessen
# ...

# %%
df2.to_csv('chicago2.csv',sep=',',encoding ='utf-8')

# %%
df2.set_index('rank',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-8acc4225ac1d> in <module>
# ----> 1 df2.set_index('Rank',inplace=True)
#       2 df2.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Rank'] are in the columns"

# %%
df2.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                       Address
# Rank
# 1        2109 W. Chicago Ave.
# 2         800 W. Randolph St.
# 3            445 N. Clark St.
# 4     914 Noyes St., Evanston
# 5          825 W. Fulton Mkt.

# %%
df2.to_csv('chicago3.csv',sep=',',encoding ='utf-8')

# %% [markdown]
# # 3. 맛집 위치를 지도에 표기하기

# %%
import numpy as np
#cmd > conda activate base > pip install folium
import folium
#cmd > conda activate base > pip install googlemaps
import googlemaps

# %%
key_fd = open('googlemapskey.txt',mode='r')
gmaps_key = key_fd.read(100)
key_fd.close()

# %%
gmaps = googlemaps.Client(key = gmaps_key)

# %%
lat = []
lng = []

for n in tqdm(df2.index):
    if df2['Address'][n] != 'Multipl':
        target_name = df2['Address'][n]+', '+'Chicago'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    else:
        lat.append(np.nan)
        lng.append(np.nan)

# %%
df2['lat'] =lat
df2['lng'] =lng
df.head()
# Out:
#    Rank                    Cafe               Menu  \
# 0     1             Old Oak Tap                BLT
# 1     2               Au Cheval      Fried Bologna
# 2     3                    Xoco  Woodland Mushroom
# 3     4               Al’s Deli         Roast Beef
# 4     5  Publican Quality Meats               PB&L
#
#                                                  URL        lat        lng
# 0  https://www.chicagomag.com/Chicago-Magazine/No...  41.895605 -87.679961
# 1  https://www.chicagomag.com/Chicago-Magazine/No...  41.884658 -87.647667
# 2  https://www.chicagomag.com/Chicago-Magazine/No...  41.890523 -87.630783
# 3  https://www.chicagomag.com/Chicago-Magazine/No...  42.058322 -87.683748
# 4  https://www.chicagomag.com/Chicago-Magazine/No...  41.886600 -87.648451

# %%
mapping = folium.Map(location=[df2['lat'].mean(),df2['lng'].mean()],zoom_start =11)
folium.Marker([df2['lat'].mean(),df2['lng'].mean()],popup='center').add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapping = folium.Map(location=[df2['lat'].mean(),df2['lng'].mean()],zoom_start =11)

for n in df2.index:
    if df2['Address'][n] != 'Multipl':
        folium.Marker([df2['lat'][n],df2['lng'][n]],
                      popup=df2['Cafe'][n]).add_to(mapping)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df2.to_csv('chicago4.csv',sep=',',encoding='utf-8')
